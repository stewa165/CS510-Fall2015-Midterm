# %%
from attractor import Attractor
# %matplotlib inline

# %%
a = Attractor()

# %%
a.evolve()
# Out:
#               t          x          y          z
# 0      0.000000   0.100000   0.000000   0.000000
# 1      0.008001   0.093160   0.021504   0.000008
# 2      0.016002   0.088440   0.041553   0.000031
# 3      0.024002   0.085582   0.060602   0.000065
# 4      0.032003   0.084383   0.079050   0.000111
# 5      0.040004   0.084683   0.097253   0.000167
# 6      0.048005   0.086360   0.115534   0.000236
# 7      0.056006   0.089326   0.134188   0.000318
# 8      0.064006   0.093522   0.153494   0.000415
# 9      0.072007   0.098914   0.173717   0.000531
# 10     0.080008   0.105491   0.195113   0.000669
# 11     0.088009   0.113260   0.217939   0.000833
# 12     0.096010   0.122252   0.242451   0.001030
# 13     0.104010   0.132511   0.268915   0.001266
# 14     0.112011   0.144100   0.297604   0.001549
# 15     0.120012   0.157101   0.328806   0.001890
# 16     0.128013   0.171608   0.362824   0.002299
# 17     0.136014   0.187736   0.399987   0.002793
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.save()

# %%
a.plot3d()

# %%
a.evolve(order=1)
# Out:
#               t          x         y          z
# 0      0.000000   0.100000  0.000000   0.000000
# 1      0.008001   0.092000  0.022400   0.000000
# 2      0.016002   0.086432  0.042829   0.000016
# 3      0.024002   0.082944  0.061847   0.000046
# 4      0.032003   0.081256  0.079932   0.000086
# 5      0.040004   0.081150  0.097493   0.000136
# 6      0.048005   0.082458  0.114891   0.000196
# 7      0.056006   0.085052  0.132442   0.000268
# 8      0.064006   0.088843  0.150434   0.000352
# 9      0.072007   0.093771  0.169131   0.000452
# 10     0.080008   0.099799  0.188783   0.000569
# 11     0.088009   0.106918  0.209627   0.000708
# 12     0.096010   0.115135  0.231899   0.000872
# 13     0.104010   0.124476  0.255833   0.001067
# 14     0.112011   0.134985  0.281668   0.001299
# 15     0.120012   0.146719  0.309650   0.001575
# 16     0.128013   0.159754  0.340036   0.001905
# 17     0.136014   0.174176  0.373098   0.002299
# 18     0.144014   0.190090  0.409126   0.002770
# ...

# %%
a.evolve(order=2)
# Out:
#               t          x         y          z
# 0      0.000000   0.100000  0.000000   0.000000
# 1      0.008001   0.093216  0.021414   0.000009
# 2      0.016002   0.088530  0.041397   0.000031
# 3      0.024002   0.085690  0.060396   0.000066
# 4      0.032003   0.084496  0.078806   0.000111
# 5      0.040004   0.084791  0.096979   0.000167
# 6      0.048005   0.086456  0.115232   0.000236
# 7      0.056006   0.089404  0.133860   0.000317
# 8      0.064006   0.093576  0.153138   0.000414
# 9      0.072007   0.098940  0.173328   0.000529
# 10     0.080008   0.105484  0.194687   0.000666
# 11     0.088009   0.113218  0.217469   0.000830
# 12     0.096010   0.122169  0.241928   0.001026
# 13     0.104010   0.132383  0.268329   0.001260
# 14     0.112011   0.143924  0.296943   0.001541
# 15     0.120012   0.156871  0.328056   0.001880
# 16     0.128013   0.171318  0.361971   0.002287
# 17     0.136014   0.187379  0.399014   0.002777
# 18     0.144014   0.205184  0.439531   0.003367
# ...
